# %% [markdown]
# # CanchaMatch
#
# _Note_: The context and dataset was created by AI, for making more challenging.
#
# ## Company
#
# CanchaMatch is a tennis clubs' administrator in Colombia. Users reserve the court through its mobile app. Usually, the app receives around 1.000 reserves per day. The company has brick powder courts, hard courts and synthetic courts. Furthermore, it offers a tennis coach, racket rental and ball machine rental.
#
# ## Context
#
# During the last few months, the company has noticed a weird reduction in income. After checking the financial reports, they found out it may happen because reservations aren’t giving the ideal return. They don’t know:
#
# - Why it happen
# - They don’t know if all locations have the same problem
# - What kind of clients have this behaviour
#
# The boss said: “We want to understand what has happened. If it’s necessary, create a model that helps us to anticipate these changes”
#
# ## Question to answer
#
# ### Essential question
# > Why is the company reducing incomes?
#
# ### Other questions
# > Does it happen the same at all locations?
#
# > Do all clients have the same behaviour?
#
# ## Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ## Reading dataset

# %%
db_original = pd.read_csv('Datasets/reservas_cancha.csv')

db_original.head()
# Out:
#    reservation_id  customer_id club_city court_type reservation_created_at  \
# 0          100000         1142    Bogotá  Synthetic    2025-06-13 09:00:00
# 1          100001         1432      Cali       Hard    2025-05-06 14:00:00
# 2          100002         1370  Medellín  Synthetic    2025-03-21 08:00:00
# 3          100003         1073  Medellín  Synthetic    2025-03-11 12:00:00
# 4          100004         1469  Medellín       Hard    2025-02-18 16:00:00
#
#   reservation_datetime match_type  player_level membership_type  \
# 0  2025-06-13 09:00:00    Singles           NaN            Gold
# 1  2025-05-31 14:00:00    Singles  Intermediate             NaN
# 2  2025-04-07 08:00:00    Singles      Beginner          Silver
# 3  2025-04-01 12:00:00    Singles  Intermediate            gold
# 4  2025-02-24 16:00:00    Singles  Intermediate          silver
#
#    rain_probability  ...  price_paid  coupon_used  payment_method  \
# ...

# %% [markdown]
# ## EDA

# %%
db_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3020 entries, 0 to 3019
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   reservation_id          3020 non-null   int64
#  1   customer_id             3020 non-null   int64
#  2   club_city               3020 non-null   object
#  3   court_type              3020 non-null   object
#  4   reservation_created_at  3020 non-null   object
#  5   reservation_datetime    3020 non-null   object
#  6   match_type              3020 non-null   object
#  7   player_level            2240 non-null   object
#  8   membership_type         2408 non-null   object
#  9   rain_probability        3020 non-null   int64
#  10  temperature_c           2960 non-null   float64
#  11  coach_reserved          3020 non-null   bool
#  12  ball_machine            3020 non-null   bool
#  13  hours_reserved          3020 non-null   float64
# ...
